# %%
from IPython.display import Image     # Import the Image function from IPython.display to display images in Jupyter environments.
from os import chdir                  # Import chdir from os module to change the current working directory.
from scipy.spatial import Delaunay  # Importar Delaunay
import numpy as np                    # Import numpy library for working with n-dimensional arrays and mathematical operations.
import gudhi as gd                    # Import gudhi library for computational topology and computational geometry.
import matplotlib.pyplot as plt       # Import pyplot from matplotlib for creating visualizations and graphs.
import argparse                       # Import argparse, a standard library for writing user-friendly command-line interfaces.
import seaborn as sns                 # Import seaborn for data visualization; it's based on matplotl.
import requests # Import requests library to make HTTP requests in Python easily.
import pandas as pd
from scipy.spatial.distance import pdist, squareform 
from sklearn.decomposition import PCA
from scipy.spatial import KDTree

# %%
import os
import requests
import csv
#Ruta del directorio que contiene los archivos CSV
ruta_directorio = "/home/jupyter-user5/multicellularity_patterns_classification-/datos_c/ad_Car/"

# Obtener una lista de todos los archivos CSV en la ruta especificada
archivos_csv = [archivo for archivo in os.listdir(ruta_directorio) if archivo.endswith('.csv')]

# Iterar sobre cada archivo CSV
for archivo_csv in archivos_csv:
    # Construir la ruta completa del archivo
    ruta_completa = os.path.join(ruta_directorio, archivo_csv)
    
    # Leer el archivo CSV y asignar nombres de columnas
    df = pd.read_csv(ruta_completa, header=None)
    nombres_columnas = ['id', 'X', 'Y',  'Tipo']  # Reemplazar con los nombres de columnas apropiados
    df.columns = nombres_columnas
    
    # Mostrar las primeras filas del DataFrame
    print("Contenido de", archivo_csv)
    print(df.head(5))
    
    # Contar el número de IDs distintos
    num_ids_distintos = df['id'].nunique()
    print("Número de IDs distintos:", num_ids_distintos)

# Obtener una lista de fenotipos únicos
    fenotipos_unicos = df['Tipo'].unique().tolist()
    print("Fenotipos únicos:", fenotipos_unicos)
# Out:
# Contenido de topology_ad_carcinoma_2_clean.csv
#        id                   X                   Y                Tipo
# 0  CellID          X_centroid          Y_centroid           phenotype
# 1    8999  20768.070521861777  11650.833568406206  Ki67+ tumor cells
# 2    9344   19005.00342465753   11177.70890410959       stromal cells
# 3   17656  19197.455301455306   11807.69022869023       stromal cells
# 4   23136   19063.15503875969   11416.31007751938       stromal cells
# Número de IDs distintos: 2481
# Fenotipos únicos: ['phenotype', 'Ki67+ tumor cells ', 'stromal cells', 'NK', 'dendritic cells', 'M2 macrophages', 'memory CD8+ T cells', 'regulatory T cells', 'effector CD8+ T cells', 'Unknown', 'memory CD4+ T cells', 'M1/M0 macrophages', 'other APCs', 'tumor cells', 'B cells', 'neutrophils', 'CD4+ T cells']
# Contenido de topology_ad_carcinoma_10_clean.csv
#        id                   X                   Y                Tipo
# 0  CellID          X_centroid          Y_centroid           phenotype
# 1    2118  30119.567567567567  23776.225225225226       stromal cells
# 2    2892   30858.14308943089  23356.053658536584  Ki67+ tumor cells
# 3    4360  29800.161094224924    23819.9179331307       stromal cells
# 4    4401   30757.19382022472   23872.13764044944       stromal cells
# Número de IDs distintos: 4323
# Fenotipos únicos: ['phenotype', 'stromal cells', 'Ki67+ tumor cells ', 'B cells', 'Unknown', 'dendritic cells', 'CD4+ T cells', 'NK', 'M2 macrophages', 'regulatory T cells', 'memory CD4+ T cells', 'effector CD8+ T cells', 'memory CD8+ T cells', 'neutrophils', 'M1/M0 macrophages', 'tumor cells', 'other APCs']
# Contenido de topology_ad_carcinoma_9_clean.csv
#        id                   X                   Y                Tipo
# 0  CellID          X_centroid          Y_centroid           phenotype
# 1    3496  23490.953100158986  20306.056438791733  Ki67+ tumor cells
# 2   10197   23438.33755274261   20750.45780590717      M2 macrophages
# 3   12221  23039.469696969696  22059.136363636364       stromal cells
# 4   12336  23043.385026737968   21876.14438502674       stromal cells
# Número de IDs distintos: 3027
# Fenotipos únicos: ['phenotype', 'Ki67+ tumor cells ', 'M2 macrophages', 'stromal cells', 'regulatory T cells', 'dendritic cells', 'M1/M0 macrophages', 'memory CD8+ T cells', 'memory CD4+ T cells', 'NK', 'Unknown', 'B cells', 'CD4+ T cells', 'tumor cells', 'neutrophils', 'effector CD8+ T cells', 'other APCs']
# Contenido de topology_ad_carcinoma_3_clean.csv
#        id                   X                   Y                 Tipo
# 0  CellID          X_centroid          Y_centroid            phenotype
# 1    5697  27292.830903790087  17278.349854227406  memory CD8+ T cells
# 2   11925   27845.70524691358  15580.699074074077        stromal cells
# 3   12385   27128.03671328672  17145.715034965036        stromal cells
# 4   14138  27526.480961923848  16572.915831663326        stromal cells
# Número de IDs distintos: 3523
# Fenotipos únicos: ['phenotype', 'memory CD8+ T cells', 'stromal cells', 'memory CD4+ T cells', 'M1/M0 macrophages', 'M2 macrophages', 'neutrophils', 'NK', 'effector CD8+ T cells', 'CD4+ T cells', 'Unknown', 'dendritic cells', 'regulatory T cells', 'tumor cells', 'Ki67+ tumor cells ', 'other APCs', 'B cells']
# Contenido de topology_ad_carcinoma_1_clean.csv
#        id                   X                   Y                Tipo
# 0  CellID          X_centroid          Y_centroid           phenotype
# 1   13997   24745.29173419773   11336.42220421394  Ki67+ tumor cells
# 2   15466  25702.172297297297  10951.297297297297       stromal cells
# 3   16160  24445.153039832287   10904.24318658281       stromal cells
# 4   20628   24795.59025270758  11267.410649819494  Ki67+ tumor cells
# Número de IDs distintos: 2861
# Fenotipos únicos: ['phenotype', 'Ki67+ tumor cells ', 'stromal cells', 'M2 macrophages', 'memory CD4+ T cells', 'memory CD8+ T cells', 'NK', 'Unknown', 'dendritic cells', 'M1/M0 macrophages', 'regulatory T cells', 'B cells', 'tumor cells', 'neutrophils', 'effector CD8+ T cells', 'CD4+ T cells']
# Contenido de topology_ad_carcinoma_8_clean.csv
#        id                  X                   Y                Tipo
# 0  CellID         X_centroid          Y_centroid           phenotype
# 1   15131  24844.80577427821  13310.511811023622       stromal cells
# 2   20177   23838.3320754717  13365.539622641509       stromal cells
# 3   22094  24823.88235294117  13504.656862745098       stromal cells
# 4   23691          23204.475  14016.083333333334  Ki67+ tumor cells
# Número de IDs distintos: 4655
# Fenotipos únicos: ['phenotype', 'stromal cells', 'Ki67+ tumor cells ', 'M2 macrophages', 'memory CD8+ T cells', 'tumor cells', 'B cells', 'regulatory T cells', 'dendritic cells', 'memory CD4+ T cells', 'neutrophils', 'NK', 'M1/M0 macrophages', 'effector CD8+ T cells', 'Unknown', 'CD4+ T cells', 'other APCs']
# Contenido de topology_ad_carcinoma_4_clean.csv
#        id                   X                   Y                Tipo
# 0  CellID          X_centroid          Y_centroid           phenotype
# 1    6465   27616.41052631579  19842.052631578947       stromal cells
# 2   11410  28198.302255639097   20397.28270676692     dendritic cells
# 3   12549   27207.59498207885   19880.16845878136                  NK
# 4   21173    28099.6189258312  19618.235294117647  Ki67+ tumor cells
# Número de IDs distintos: 2642
# Fenotipos únicos: ['phenotype', 'stromal cells', 'dendritic cells', 'NK', 'Ki67+ tumor cells ', 'neutrophils', 'M2 macrophages', 'Unknown', 'regulatory T cells', 'tumor cells', 'memory CD4+ T cells', 'memory CD8+ T cells', 'M1/M0 macrophages', 'CD4+ T cells', 'B cells', 'effector CD8+ T cells', 'other APCs']
# Contenido de topology_ad_carcinoma_12_clean.csv
#        id                  X                   Y                 Tipo
# 0  CellID         X_centroid          Y_centroid            phenotype
# 1   12067  39695.48140495868   36455.53099173554    M1/M0 macrophages
# 2   12898  42757.48666666666            34405.86  memory CD4+ T cells
# 3   16263  40545.73449401523  35408.682263329705   Ki67+ tumor cells
# 4   18115   41466.6168224299  34720.214953271025        stromal cells
# Número de IDs distintos: 1964
# Fenotipos únicos: ['phenotype', 'M1/M0 macrophages', 'memory CD4+ T cells', 'Ki67+ tumor cells ', 'stromal cells', 'memory CD8+ T cells', 'tumor cells', 'NK', 'effector CD8+ T cells', 'regulatory T cells', 'Unknown', 'dendritic cells', 'M2 macrophages', 'neutrophils', 'CD4+ T cells', 'B cells']
# Contenido de topology_ad_carcinoma_15_clean.csv
#        id                   X                  Y                Tipo
# 0  CellID          X_centroid         Y_centroid           phenotype
# 1    8907  37595.469121140144  44845.77790973872  Ki67+ tumor cells
# 2   16324  37343.879781420765  44502.38524590164       stromal cells
# 3   17073   37111.84586466166   44171.4984962406  Ki67+ tumor cells
# 4   20701   37246.81621287129  44674.61076732673  Ki67+ tumor cells
# Número de IDs distintos: 1575
# Fenotipos únicos: ['phenotype', 'Ki67+ tumor cells ', 'stromal cells', 'tumor cells', 'M2 macrophages', 'regulatory T cells', 'NK', 'memory CD4+ T cells', 'effector CD8+ T cells', 'memory CD8+ T cells', 'dendritic cells', 'Unknown', 'neutrophils', 'M1/M0 macrophages', 'CD4+ T cells', 'B cells']
# Contenido de topology_ad_carcinoma_5_clean.csv
#        id                   X                   Y                 Tipo
# 0  CellID          X_centroid          Y_centroid            phenotype
# 1     309  30029.700743494424   22341.00557620818        stromal cells
# 2    2375   29961.76923076923  22412.506903353056  memory CD4+ T cells
# 3    4235   26782.28571428572   22612.08035714286  memory CD4+ T cells
# 4    4612   27148.48091603053  23065.885496183208              Unknown
# Número de IDs distintos: 3159
# Fenotipos únicos: ['phenotype', 'stromal cells', 'memory CD4+ T cells', 'Unknown', 'NK', 'M2 macrophages', 'CD4+ T cells', 'neutrophils', 'effector CD8+ T cells', 'M1/M0 macrophages', 'regulatory T cells', 'memory CD8+ T cells', 'Ki67+ tumor cells ', 'dendritic cells', 'tumor cells', 'B cells', 'other APCs']
# Contenido de topology_ad_carcinoma_11_clean.csv
#        id                   X                   Y           Tipo
# 0  CellID          X_centroid          Y_centroid      phenotype
# 1    3109   40207.87962962963  31499.777777777777  stromal cells
# 2    4861  40668.522012578615   31480.02358490566  stromal cells
# 3   22156   43116.42068965517  31008.165517241378  stromal cells
# 4   22165   42812.96610169492   30952.02824858757  stromal cells
# Número de IDs distintos: 2209
# Fenotipos únicos: ['phenotype', 'stromal cells', 'Ki67+ tumor cells ', 'M2 macrophages', 'NK', 'Unknown', 'M1/M0 macrophages', 'memory CD4+ T cells', 'dendritic cells', 'memory CD8+ T cells', 'regulatory T cells', 'effector CD8+ T cells', 'tumor cells', 'neutrophils', 'CD4+ T cells', 'B cells']
# Contenido de topology_ad_carcinoma_6_clean.csv
#        id                  X                   Y                 Tipo
# 0  CellID         X_centroid          Y_centroid            phenotype
# 1    7489  21813.84426229508             16891.5          neutrophils
# 2    9977  21935.27927927928  16841.882882882885  memory CD4+ T cells
# 3   24172  22464.20478723404   17180.45478723404        stromal cells
# 4   26620         22305.3125  17246.902777777777  memory CD4+ T cells
# Número de IDs distintos: 1425
# Fenotipos únicos: ['phenotype', 'neutrophils', 'memory CD4+ T cells', 'stromal cells', 'NK', 'regulatory T cells', 'M2 macrophages', 'tumor cells', 'Ki67+ tumor cells ', 'dendritic cells', 'M1/M0 macrophages', 'memory CD8+ T cells', 'other APCs', 'CD4+ T cells', 'Unknown', 'effector CD8+ T cells', 'B cells']
# Contenido de topology_ad_carcinoma_7_clean.csv
#        id                   X                   Y                 Tipo
# 0  CellID          X_centroid          Y_centroid            phenotype
# 1    2639  25417.118811881188   16940.72277227723        stromal cells
# 2    5700   26412.29840546697  17639.646924829158        stromal cells
# 3   12636   23588.91095890411  16661.739726027397        stromal cells
# 4   12820  24469.039285714287  16390.932142857142  memory CD4+ T cells
# Número de IDs distintos: 3383
# Fenotipos únicos: ['phenotype', 'stromal cells', 'memory CD4+ T cells', 'M2 macrophages', 'memory CD8+ T cells', 'regulatory T cells', 'M1/M0 macrophages', 'NK', 'tumor cells', 'B cells', 'dendritic cells', 'Unknown', 'neutrophils', 'effector CD8+ T cells', 'CD4+ T cells', 'Ki67+ tumor cells ', 'other APCs']
# Contenido de topology_ad_carcinoma_13_clean.csv
#        id                   X                   Y                 Tipo
# 0  CellID          X_centroid          Y_centroid            phenotype
# 1      56   40544.09087221095  39275.202028397565                   NK
# 2    2960  40391.161516853936   38730.12359550562        stromal cells
# 3    8603   40032.73770491804   39511.90983606558              Unknown
# 4   12804  40646.522935779816   39036.31192660551  memory CD4+ T cells
# Número de IDs distintos: 1799
# Fenotipos únicos: ['phenotype', 'NK', 'stromal cells', 'Unknown', 'memory CD4+ T cells', 'CD4+ T cells', 'dendritic cells', 'effector CD8+ T cells', 'M2 macrophages', 'M1/M0 macrophages', 'memory CD8+ T cells', 'Ki67+ tumor cells ', 'neutrophils', 'regulatory T cells', 'tumor cells', 'other APCs', 'B cells']
# Contenido de topology_ad_carcinoma_14_clean.csv
#        id                   X                  Y           Tipo
# 0  CellID          X_centroid         Y_centroid      phenotype
# 1    1981   49681.50340136055   39567.5850340136  stromal cells
# 2    3364   49919.39962825279  39985.45910780669  stromal cells
# 3    3656   50189.98611111111  40330.47048611111  stromal cells
# 4    5321  49403.193954659946  40643.87909319899  stromal cells
# Número de IDs distintos: 2872
# Fenotipos únicos: ['phenotype', 'stromal cells', 'memory CD8+ T cells', 'effector CD8+ T cells', 'CD4+ T cells', 'Unknown', 'memory CD4+ T cells', 'Ki67+ tumor cells ', 'dendritic cells', 'M1/M0 macrophages', 'M2 macrophages', 'NK', 'tumor cells', 'regulatory T cells', 'B cells', 'other APCs', 'neutrophils']
